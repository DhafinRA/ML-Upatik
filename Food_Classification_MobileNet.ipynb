# %% [markdown]
# # Image Classification

# %%
import random
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import matplotlib.image as mpimg
# from tensorflow.keras.applications.MobileNet import MobileNet

# %%
# Read Images
img = mpimg.imread('Dataset/Train/Nasi Ikan/ikan1.jpg')

# Output Images
plt.imshow(img)

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255,
                                                            horizontal_flip=True,
                                                            vertical_flip=True,
                                                            rotation_range=60,
                                                            width_shift_range=0.8,
                                                            height_shift_range=0.8,)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# %%
train_dir = "Dataset\Train"
test_dir = "Dataset\Test"
images = []

for food_folder in sorted(os.listdir(train_dir)):
    food_items = os.listdir(os.path.join(train_dir, food_folder))
    food_selected = np.random.choice(food_items)
    images.append(os.path.join(train_dir, food_folder, food_selected))

fig = plt.figure(1, figsize=(25, 25))

for subplot, image_ in enumerate(images):
    category = image_.split('/')[-2]  # Mengambil nama kategori dari path
    imgs = plt.imread(image_)
    fig = plt.subplot(5, 4, subplot+1)
    fig.set_title(category, pad=10, size=18)
    plt.imshow(imgs)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 7
#       5 for food_folder in sorted(os.listdir(train_dir)):
#       6     food_items = os.listdir(os.path.join(train_dir, food_folder))
# ----> 7     food_selected = np.random.choice(food_items)
#       8     images.append(os.path.join(train_dir, food_folder, food_selected))
#      10 fig = plt.figure(1, figsize=(25, 25))
#
# File mtrand.pyx:934, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: 'a' cannot be empty unless no samples are taken
